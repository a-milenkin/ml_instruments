# %% [markdown]
# # <center> [⚡ ClearML + Lightning в CV: учим GAN 🛠](https://stepik.org/lesson/1500763/step/9?unit=1520877)
#
# Вам необходимо **сдать файл** (или несколько файлов) с расширением `любое_имя.py` и **ссылку** на результат эксперимента в `ClearML`:
#
# **Основное задание (5 баллов):**
#
# 1. Структурировать код с использованием `PyTorch Lightning`:
#
# * Создать класс, наследующий от `LightningModule`, который реализует GAN.
# * Разбить код на методы: `training_step, configure_optimizers, validation_step` (если требуется) и т. д.
#
# 2. Создать `LightningDataModule`:
# * Реализовать методы `prepare_data(), setup(stage), train_dataloader()` (и, по желанию, `val_dataloader()`) для загрузки датасета MNIST.
#
# 3. Интегрировать `ClearML`:
# * Проверять вначале работы скрипта наличие всех необходимых для работы `ClearML credentials`, при необходимости просить их ввести.
# * Логировать гиперпараметры
# * Логировать метрики (например, потери генератора и дискриминатора)
# * Логировать промежуточные сгенерированные изображения, чтобы они отображались на вкладке `Debug samples` в UI.
#
# 4. Сохранение чекпоинтов:
# * Использовать возможности `Lightning` для автоматического сохранения чекпоинтов модели.
#
# **Дополнительное задание (2 балла):**
# 1. Добавьте считывание параметра `--epoch` при запуске файла на исполнение, который будет отвечать за количество эпох обучения (значение по умолчанию `10`).
# 2. Добавьте считывание параметра `--debug_samples_epoch` при запуске файла на исполнение, который будет отвечать за частоту логирования отладочных сэмплов: 1 - каждую эпоху, 2 - каждую вторую эпоху и.т.д (значение по умолчанию `1`).
# Пример команды: `python любое_имя.py --epoch 20 --debug_samples_epoch 2`
#
# **Задание со звездочкой 🌟 (1 балл):**
#
# Создайте репозиторий на одном из хостингов: `GitHub, GitLab, GitVerse`
# Загрузите на хостинг свое решение, добавив `README` файл с краткой информацией о проекте и его запуском
# Прикрепите ссылку на репозиторий в текстовом поле.
# Файл должен запускаться командой `python любое_имя.py` и отрабатывать до конца без падений.
#
# Так же в текстовом поле приложите ссылку с результатами, которую можно создать в `ClearML` на странице эксперимента в `меню -> Share`.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# %%
# Гиперпараметры
batch_size = 64
lr = 0.0002
num_epochs = 10
noise_dim = 100
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Подготовка датасета MNIST
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))]
)
dataset = datasets.MNIST(root="./data", train=True, download=True, transform=transform)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Out:
# ...
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# ...
# 100%|██████████| 9912422/9912422 [00:01<00:00, 8256739.03it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# ...
# 100%|██████████| 28881/28881 [00:00<00:00, 223295.72it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# ...
# 100%|██████████| 1648877/1648877 [00:00<00:00, 2071931.98it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# ...
# 100%|██████████| 4542/4542 [00:00<00:00, 9597243.71it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
# Определение генератора
class Generator(nn.Module):
    def __init__(self, noise_dim):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            # Вход: вектор шума размера noise_dim
            nn.Linear(noise_dim, 256 * 7 * 7),
            nn.ReLU(True),
            nn.Unflatten(1, (256, 7, 7)),
            # Состояние: (256, 7, 7)
            nn.ConvTranspose2d(
                256, 128, kernel_size=4, stride=2, padding=1, bias=False
            ),  # -> (128, 14, 14)
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(
                128, 1, kernel_size=4, stride=2, padding=1, bias=False
            ),  # -> (1, 28, 28)
            nn.Tanh(),
        )

    def forward(self, input):
        return self.main(input)


# Определение дискриминатора
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            # Вход: изображение (1, 28, 28)
            nn.Conv2d(
                1, 64, kernel_size=4, stride=2, padding=1, bias=False
            ),  # -> (64, 14, 14)
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(
                64, 128, kernel_size=4, stride=2, padding=1, bias=False
            ),  # -> (128, 7, 7)
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Flatten(),
            nn.Linear(128 * 7 * 7, 1),
            nn.Sigmoid(),
        )

    def forward(self, input):
        return self.main(input)

# %%
# Создаем модели
netG = Generator(noise_dim).to(device)
netD = Discriminator().to(device)

# Определяем функцию потерь и оптимизаторы
criterion = nn.BCELoss()
optimizerD = optim.Adam(netD.parameters(), lr=lr, betas=(0.5, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(0.5, 0.999))

# Метки
real_label = 1.0
fake_label = 0.0

# %%
# Основной цикл обучения
for epoch in range(num_epochs):
    for i, (data, _) in enumerate(dataloader):
        ############################
        #  Обновляем дискриминатор
        ############################
        netD.zero_grad()
        # Обучение на реальных изображениях
        real_images = data.to(device)
        b_size = real_images.size(0)
        label = torch.full((b_size,), real_label, dtype=torch.float, device=device)

        output = netD(real_images).view(-1)
        errD_real = criterion(output, label)
        errD_real.backward()
        D_x = output.mean().item()

        # Обучение на фейковых изображениях
        noise = torch.randn(b_size, noise_dim, device=device)
        fake_images = netG(noise)
        label.fill_(fake_label)
        output = netD(fake_images.detach()).view(-1)
        errD_fake = criterion(output, label)
        errD_fake.backward()
        D_G_z1 = output.mean().item()

        errD = errD_real + errD_fake
        optimizerD.step()

        ############################
        #  Обновляем генератор
        ############################
        netG.zero_grad()
        label.fill_(
            real_label
        )  # Для генератора "фейковые" метки считаются как реальные
        output = netD(fake_images).view(-1)
        errG = criterion(output, label)
        errG.backward()
        D_G_z2 = output.mean().item()
        optimizerG.step()

        if i % 300 == 0:
            print(
                "[%d/%d][%d/%d]\tLoss_D: %.4f\tLoss_G: %.4f\tD(x): %.4f\tD(G(z)): %.4f / %.4f"
                % (
                    epoch,
                    num_epochs,
                    i,
                    len(dataloader),
                    errD.item(),
                    errG.item(),
                    D_x,
                    D_G_z1,
                    D_G_z2,
                )
            )

    # Сохраняем сэмплы генератора каждые 2 эпохи
    if epoch % 2 == 0:
        with torch.no_grad():
            fixed_noise = torch.randn(64, noise_dim, device=device)
            fake = netG(fixed_noise).detach().cpu()
            os.makedirs("output", exist_ok=True)
            torchvision.utils.save_image(
                fake, f"output/fake_samples_epoch_{epoch}.png", normalize=True
            )
# Out:
# [0/10][0/938]	Loss_D: 1.3175	Loss_G: 0.8938	D(x): 0.5733	D(G(z)): 0.5213 / 0.4172
# [0/10][300/938]	Loss_D: 0.0021	Loss_G: 7.1663	D(x): 0.9989	D(G(z)): 0.0009 / 0.0008
# [0/10][600/938]	Loss_D: 0.0007	Loss_G: 8.0991	D(x): 0.9996	D(G(z)): 0.0003 / 0.0003
# [0/10][900/938]	Loss_D: 0.0242	Loss_G: 4.8106	D(x): 0.9880	D(G(z)): 0.0115 / 0.0091
# [1/10][0/938]	Loss_D: 0.0167	Loss_G: 5.3511	D(x): 0.9897	D(G(z)): 0.0059 / 0.0050
# [1/10][300/938]	Loss_D: 0.5373	Loss_G: 2.5472	D(x): 0.8024	D(G(z)): 0.2376 / 0.1044
# [1/10][600/938]	Loss_D: 0.6278	Loss_G: 2.3498	D(x): 0.8830	D(G(z)): 0.3795 / 0.1055
# [1/10][900/938]	Loss_D: 0.3221	Loss_G: 2.5783	D(x): 0.8929	D(G(z)): 0.1707 / 0.0955
# [2/10][0/938]	Loss_D: 0.3158	Loss_G: 2.7685	D(x): 0.9203	D(G(z)): 0.1878 / 0.0816
# [2/10][300/938]	Loss_D: 0.4891	Loss_G: 3.7518	D(x): 0.9436	D(G(z)): 0.3114 / 0.0344
# [2/10][600/938]	Loss_D: 0.3738	Loss_G: 1.5768	D(x): 0.7862	D(G(z)): 0.0808 / 0.2451
# ...

# %%
# Сохраняем финальные веса генератора
torch.save(netG.state_dict(), "netG_final.pth")

# %% [markdown]
# # Решение

# %% [markdown]
# !pip install clearml lightning -q

# %% [markdown]
# # Запись файлов для сдачи на Stepik

# %%
# %%writefile gan_module.py

import torch
import torch.nn as nn
import torchvision.utils as vutils
import torchvision.transforms as transforms
from lightning import LightningModule
from torch.optim import Adam
from clearml import Task


class Generator(nn.Module):
    def __init__(self, noise_dim):
        super(Generator, self).__init__()
        self.noise_dim = noise_dim
        self.main = nn.Sequential(
            nn.Linear(noise_dim, 256 * 7 * 7),
            nn.ReLU(True),
            nn.Unflatten(1, (256, 7, 7)),
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),  # -> (128, 14, 14)
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 1, kernel_size=4, stride=2, padding=1, bias=False),    # -> (1, 28, 28)
            nn.Tanh()
        )
        
    def forward(self, x):
        return self.main(x)

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=4, stride=2, padding=1, bias=False),  # -> (64, 14, 14)
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False), # -> (128, 7, 7)
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Flatten(),
            nn.Linear(128 * 7 * 7, 1),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        return self.main(x)

class GAN(LightningModule):
    def __init__(self, noise_dim=100, lr=0.0002, betas=(0.5, 0.999), debug_samples_epoch=1):
        super(GAN, self).__init__()
        self.save_hyperparameters()
        self.noise_dim = noise_dim
        self.lr = lr
        self.betas = betas
        self.debug_samples_epoch = debug_samples_epoch
        self.generator = Generator(noise_dim)
        self.discriminator = Discriminator()
        self.criterion = nn.BCELoss()
        # Отключаем автоматическую оптимизацию
        self.automatic_optimization = False

    def forward(self, z):
        return self.generator(z)
    
    def training_step(self, batch, batch_idx):
        opt_d, opt_g = self.optimizers()  # Получаем оптимизаторы: дискриминатора и генератора
        real_images, _ = batch
        batch_size = real_images.size(0)
        device = real_images.device
        
        real_labels = torch.full((batch_size,), 1.0, device=device)
        fake_labels = torch.full((batch_size,), 0.0, device=device)
        
        # Обновление дискриминатора
        opt_d.zero_grad()
        output_real = self.discriminator(real_images).view(-1)
        loss_real = self.criterion(output_real, real_labels)
        
        noise = torch.randn(batch_size, self.noise_dim, device=device)
        fake_images = self.generator(noise)
        output_fake = self.discriminator(fake_images.detach()).view(-1)
        loss_fake = self.criterion(output_fake, fake_labels)
        loss_D = loss_real + loss_fake
        
        self.manual_backward(loss_D)
        opt_d.step()
        
        # Обновление генератора
        opt_g.zero_grad()
        noise = torch.randn(batch_size, self.noise_dim, device=device)
        fake_images = self.generator(noise)
        output = self.discriminator(fake_images).view(-1)
        loss_G = self.criterion(output, real_labels)
        
        self.manual_backward(loss_G)
        opt_g.step()
        
        self.log('loss_D', loss_D, prog_bar=True, on_epoch=True)
        self.log('loss_G', loss_G, prog_bar=True, on_epoch=True)
        Task.current_task().get_logger().report_scalar("Loss", "Discriminator", loss_D.item(), iteration=self.global_step)
        Task.current_task().get_logger().report_scalar("Loss", "Generator", loss_G.item(), iteration=self.global_step)
        return {"loss_D": loss_D, "loss_G": loss_G}

    def validation_step(self, batch, batch_idx):
        # Логирование сгенерированных изображений, если текущая эпоха кратна debug_samples_epoch
        if self.current_epoch % self.hparams.debug_samples_epoch == 0:
            device = self.device
            fixed_noise = torch.randn(16, self.noise_dim, device=device)
            fake_images = self.generator(fixed_noise)
            grid = vutils.make_grid(fake_images, normalize=True)
            pil_img = transforms.ToPILImage()(grid.cpu())
            Task.current_task().get_logger().report_image("Validation Images", f"Epoch {self.current_epoch}", iteration=self.global_step, image=pil_img)
        self.log("val_dummy", 0, prog_bar=False)
    
    def configure_optimizers(self):
        optimizerD = Adam(self.discriminator.parameters(), lr=self.lr, betas=self.betas)
        optimizerG = Adam(self.generator.parameters(), lr=self.lr, betas=self.betas)
        return [optimizerD, optimizerG], []
# Out:
# Overwriting gan_module.py

# %%
# %%writefile gan_datamodule.py

import torch
from torch.utils.data import DataLoader
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from lightning import LightningDataModule

class MNISTDataModule(LightningDataModule):
    def __init__(self, data_dir='./data', batch_size=64):
        super().__init__()
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5,), (0.5,))  # нормализация для диапазона [-1, 1]
        ])
    
    def prepare_data(self):
        # Скачивание данных – вызывается только один раз
        datasets.MNIST(root=self.data_dir, train=True, download=True)
        datasets.MNIST(root=self.data_dir, train=False, download=True)
    
    def setup(self, stage=None):
        # При обучении создаём train и validation наборы
        if stage == "fit" or stage is None:
            self.mnist_train = datasets.MNIST(root=self.data_dir, train=True, transform=self.transform)
            # Используем часть тестового набора как валидацию
            self.mnist_val = datasets.MNIST(root=self.data_dir, train=False, transform=self.transform)
        if stage == "test":
            self.mnist_test = datasets.MNIST(root=self.data_dir, train=False, transform=self.transform)
    
    def train_dataloader(self):
        return DataLoader(self.mnist_train, batch_size=self.batch_size, shuffle=True, num_workers=4)
    
    def val_dataloader(self):
        # Используем валид. набор, созданный в setup()
        return DataLoader(self.mnist_val, batch_size=self.batch_size, shuffle=False, num_workers=4)
# Out:
# Overwriting gan_datamodule.py

# %%
# %%writefile train.py
#!/usr/bin/env python
import os
import argparse
from lightning import Trainer, seed_everything
from lightning.pytorch.callbacks import ModelCheckpoint
from gan_module import GAN
from gan_datamodule import MNISTDataModule
from clearml import Task
import torch

def check_clearml_credentials():
    required_vars = ["CLEARML_API_HOST", "CLEARML_WEB_HOST", "CLEARML_API_ACCESS_KEY", "CLEARML_API_SECRET_KEY"]
    missing = [var for var in required_vars if var not in os.environ]
    if missing:
        raise EnvironmentError(f"Missing ClearML credentials: {missing}")
    else:
        print("All ClearML credentials are present.")

def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--epoch", type=int, default=10, help="Количество эпох обучения")
    parser.add_argument("--debug_samples_epoch", type=int, default=1, help="Частота логирования отладочных сэмплов (1 - каждую эпоху, 2 - каждую вторую и т.д.)")
    args = parser.parse_args()
    
    # Проверка наличия ClearML credentials
    check_clearml_credentials()
    
    # Инициализация ClearML задачи
    task = Task.init(project_name="GAN Experiment", task_name="GAN MNIST Lightning")
    
    # Логирование гиперпараметров через ClearML
    config = {
        "batch_size": 64,
        "lr": 0.0002,
        "num_epochs": args.epoch,
        "noise_dim": 100,
        "debug_samples_epoch": args.debug_samples_epoch
    }
    config = task.connect(config)
    
    # Установка seed для воспроизводимости
    seed_everything(42)
    
    # Инициализация модели GAN с передачей debug_samples_epoch
    model = GAN(noise_dim=config["noise_dim"], lr=config["lr"], debug_samples_epoch=config["debug_samples_epoch"])
    
    # Инициализация DataModule для MNIST
    dm = MNISTDataModule(batch_size=config["batch_size"])
    
    # Настройка колбэков: сохранение чекпоинтов и мониторинг learning rate
    checkpoint_callback = ModelCheckpoint(
        monitor="loss_G", mode="min", save_top_k=1, filename="gan-{epoch:02d}-{loss_G:.2f}"
    )
    
    trainer = Trainer(
        max_epochs=config["num_epochs"],
        accelerator="gpu" if torch.cuda.is_available() else "cpu",
        devices=1,
        callbacks=[checkpoint_callback],
        log_every_n_steps=50
    )
    
    # Запуск обучения
    trainer.fit(model, datamodule=dm)

    task.close()

if __name__ == "__main__":
    main()
# Out:
# Overwriting train.py

# %%
# Проверка
# !python train.py

# %%
# Проверка с доп.заданием
# !python train.py --epoch 10 --debug_samples_epoch 2
# Out:
# ClearML Task: created new task id=4b8590cccb1c404db7aca28b46e45285
# ClearML results page: https://app.clear.ml/projects/b1d6b45c530b4076be9e34011368c7c6/experiments/4b8590cccb1c404db7aca28b46e45285/output/log
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name          | Type          | Params | Mode
# --------------------------------------------------------
# 0 | generator     | Generator     | 1.8 M  | train
# 1 | discriminator | Discriminator | 138 K  | train
# ...
